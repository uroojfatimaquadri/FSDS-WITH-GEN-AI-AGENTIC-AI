# %%
import pandas as pd
#SAMPLE DATA
data= {
    "Month": ["Jan" , "Feb" , "Mar" , "Apr" , "May" , "Jun"],
    "Sales": [10000,12000,15000,13000,17000,16000],
    "Profit":[2000, 3000 ,4000, 2500,3500,3000]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#   Month  Sales  Profit
# 0   Jan  10000    2000
# 1   Feb  12000    3000
# 2   Mar  15000    4000
# 3   Apr  13000    2500
# 4   May  17000    3500
# 5   Jun  16000    3000

# %%
import matplotlib.pyplot as plt
#LINE PLOT: Sales over Time

plt.figure(figsize=(8,5))
plt.plot(df['Month'], df['Sales'], color='blue', marker='o', linestyle='-' , label='Sales')
plt.title('Sales Trend Over Months')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid('true')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #BAR PLOT: SALES VS PROFIT by Month

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
width = 0.3

plt.bar(df['Month'], df['Sales'], width=width, color='skyblue', label='Sales')
plt.bar(df['Month'], df['Profit'], width=width, color='orange', label='Profit', bottom=df['Sales'])

plt.title('Comparison of Sales and Profit by Month')
plt.xlabel('Month')
plt.ylabel('Amount')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#PIE CHART: Profit Distribution by Month

plt.figure(figsize=(7,7))

plt.pie(df['Profit'],labels=df['Month'], autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(df))))

plt.title('Profit Distribution by Month')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#SCATTER PLOT: Sales VS Profit Correlation

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.scatter(df['Sales'],df['Profit'], color='green', s=100, edgecolors='black')
plt.title('Sales VS Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#HISTOGRAM: Distributions of Sales
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.hist(df['Sales'], color='purple' , bins= 5, egdecolors='black')
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 4
#       2 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(8,5))
# ----> 4 plt.hist(df['Sales'], color='purple' , bins= 5, egdecolors='black')
#       5 plt.title('Distribution of Sales')
#       6 plt.xlabel('Sales')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3469, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3444 @_copy_docstring_and_deprecators(Axes.hist)
#    3445 def hist(
#    3446     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3467     BarContainer | Polygon | list[BarContainer | Polygon],
#    3468 ]:
# -> 3469     return gca().hist(
#    3470         x,
#    3471         bins=bins,
#    3472         range=range,
#    3473         density=density,
#    3474         weights=weights,
#    3475         cumulative=cumulative,
#    3476         bottom=bottom,
#    3477         histtype=histtype,
#    3478         align=align,
#    3479         orientation=orientation,
#    3480         rwidth=rwidth,
#    3481         log=log,
#    3482         color=color,
#    3483         label=label,
#    3484         stacked=stacked,
#    3485         **({"data": data} if data is not None else {}),
#    3486         **kwargs,
#    3487     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:7266, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7258 p = patch[0]
#    7259 kwargs.update({
#    7260     'hatch': next(hatches),
#    7261     'linewidth': next(linewidths),
#    (...)
#    7264     'facecolor': next(facecolors),
#    7265 })
# -> 7266 p._internal_update(kwargs)
#    7267 if lbl is not None:
#    7268     p.set_label(lbl)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'egdecolors'

# %%
#BOX PLOT: Profit Distribution
plt.figure(figsize=(8,5))
plt.boxplot(df['Profit'], vert=False, patch_artist=True, boxprops=dict(facecolor="lightgreen"))
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.tight_layout()
plt.show()

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\urooj\anaconda3\lib\site-packages (5.49.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.120.0)
# Requirement already satisfied: ffmpy in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.6.4)
# Requirement already satisfied: gradio-client==1.13.3 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (3.11.4)
# Requirement already satisfied: packaging in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (2.10.3)
# Requirement already satisfied: pydub in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.14.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\urooj\anaconda3\lib\site-packages (from gradio-client==1.13.3->gradio) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=13.0 in c:\users\urooj\anaconda3\lib\site-packages (from gradio-client==1.13.3->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\urooj\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\urooj\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\urooj\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.3)
# Requirement already satisfied: certifi in c:\users\urooj\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\urooj\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\urooj\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\urooj\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: requests in c:\users\urooj\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\urooj\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\urooj\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\urooj\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\urooj\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\urooj\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\urooj\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.27.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\urooj\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\urooj\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\urooj\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\urooj\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\urooj\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\urooj\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\urooj\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\urooj\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\urooj\anaconda3\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\urooj\anaconda3\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import pandas as pd
import matplotlib.pyplot as plt

# %%
#SAMPLE DATA
data= {
    "Month": ["Jan" , "Feb" , "Mar" , "Apr" , "May" , "Jun"],
    "Sales": [10000,12000,15000,13000,17000,16000],
    "Profit":[2000, 3000 ,4000, 2500,3500,3000]
}
df=pd.DataFrame(data)
#FUNCTION TO RETURM SELECTED PLOT
def generate_plot(plot_type):
    fig= plt.figure(figsize(8,5))

    if plot_type == "Line Plot":
       plt.plot(df['Month'], df['Sales'], color='blue', marker='o', linestyle='-' , label='Sales')
       plt.title('Sales Trend Over Months')
       plt.xlabel('Month')
       plt.ylabel('Sales')
       plt.grid('true')
       plt.legend()
       plt.tight_layout()
       plt.show()

    elif plot_type == "Stacked Bar Chart":
         plt.figure(figsize=(10,6))
         width = 0.3

         plt.bar(df['Month'], df['Sales'], width=width, color='skyblue', label='Sales')
         plt.bar(df['Month'], df['Profit'], width=width, color='orange', label='Profit', bottom=df['Sales'])

         plt.title('Comparison of Sales and Profit by Month')
         plt.xlabel('Month')
         plt.ylabel('Amount')
         plt.legend()
         plt.tight_layout()
         plt.show()

    elif plot_type == "Pie Chart":
         plt.figure(figsize=(7,7))

         plt.pie(df['Profit'],labels=df['Month'], autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(df))))

         plt.title('Profit Distribution by Month')
         plt.legend()
         plt.tight_layout()
         plt.show()

    elif plot_type == "Scatter Plot":
         plt.figure(figsize=(8,5))
         plt.scatter(df['Sales'],df['Profit'], color='green', s=100, edgecolors='black')
         plt.title('Sales VS Profit')
         plt.xlabel('Sales')
         plt.ylabel('Profit')
         plt.grid(True)
         plt.tight_layout()
         plt.show()

    elif plot_type == "Histogram":
         plt.figure(figsize=(8,5))
         plt.hist(df['Sales'], color='purple' , bins= 5, egdecolors='black')
         plt.title('Distribution of Sales')
         plt.xlabel('Sales')
         plt.ylabel('Frequency')
         plt.tight_layout()
         plt.show()

    elif plot_type == "Box Plot":
         plt.boxplot(df['Profit'], vert=False, patch_artist=True, boxprops=dict(facecolor="lightgreen"))
         plt.title('Profit Distribution')
         plt.xlabel('Profit')

         plt.tight_layout()
    return fig


#Gradio UI
demo= gr.Interface(
    fn=generate_plot,
    inputs=gr.Radio(
         ["Line Plot", "Stacked Bar Chart", "Pie Chart", "Scatter Plot", "Histogram", "Box plot"]
         label= "Choose Plot Type"
),
        outputs=gr.Plot(label="Visualization"),
        title="Sales and Profit Visual Explorer",
        discription="Choose a chart type to visualize the data."
    )
    demo.launch()
# Out:
#   Cell In[39], line 78
#     ["Line Plot", "Stacked Bar Chart", "Pie Chart", "Scatter Plot", "Histogram", "Box plot"]
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gradio as gr

# SAMPLE DATA
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [10000, 12000, 15000, 13000, 17000, 16000],
    "Profit": [2000, 3000, 4000, 2500, 3500, 3000]
}
df = pd.DataFrame(data)

# FUNCTION TO RETURN SELECTED PLOT
def generate_plot(plot_type):
    fig = plt.figure(figsize=(8, 5))

    if plot_type == "Line Plot":
        plt.plot(df['Month'], df['Sales'], color='blue', marker='o', linestyle='-', label='Sales')
        plt.title('Sales Trend Over Months')
        plt.xlabel('Month')
        plt.ylabel('Sales')
        plt.grid(True)
        plt.legend()
        plt.tight_layout()

    elif plot_type == "Stacked Bar Chart":
        plt.bar(df['Month'], df['Sales'], color='skyblue', label='Sales')
        plt.bar(df['Month'], df['Profit'], color='orange', label='Profit', bottom=df['Sales'])
        plt.title('Comparison of Sales and Profit by Month')
        plt.xlabel('Month')
        plt.ylabel('Amount')
        plt.legend()
        plt.tight_layout()

    elif plot_type == "Pie Chart":
        plt.pie(df['Profit'], labels=df['Month'], autopct='%1.1f%%',
                startangle=140, colors=plt.cm.Paired(range(len(df))))
        plt.title('Profit Distribution by Month')
        plt.tight_layout()

    elif plot_type == "Scatter Plot":
        plt.scatter(df['Sales'], df['Profit'], color='green', s=100, edgecolors='black')
        plt.title('Sales VS Profit')
        plt.xlabel('Sales')
        plt.ylabel('Profit')
        plt.grid(True)
        plt.tight_layout()

    elif plot_type == "Histogram":
        plt.hist(df['Sales'], color='purple', bins=5, edgecolor='black')
        plt.title('Distribution of Sales')
        plt.xlabel('Sales')
        plt.ylabel('Frequency')
        plt.tight_layout()

    elif plot_type == "Box Plot":
        plt.boxplot(df['Profit'], vert=False, patch_artist=True,
                    boxprops=dict(facecolor="lightgreen"))
        plt.title('Profit Distribution')
        plt.xlabel('Profit')
        plt.tight_layout()

    return fig


# GRADIO UI
demo = gr.Interface(
    fn=generate_plot,
    inputs=gr.Radio(
        ["Line Plot", "Stacked Bar Chart", "Pie Chart", "Scatter Plot", "Histogram", "Box Plot"],
        label="Choose Plot Type"
    ),
    outputs=gr.Plot(label="Visualization"),
    title="Sales and Profit Visual Explorer",
    description="Choose a chart type to visualize the data."
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio\flagged\dataset1.csv
